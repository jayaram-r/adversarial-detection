# %%
import numpy as np
import os
import pickle
from sklearn.model_selection import StratifiedKFold
from helpers.utils import (
    metrics_varying_positive_class_proportion, 
    plot_performance_comparison
)
from pprint import pprint

# %%
def generate_score_data(loc, n_pos, n_neg, n_folds, seed):
    scores_pos = np.random.normal(loc=loc[0], scale=2.5, size=n_pos)
    scores_neg = np.random.normal(loc=loc[1], scale=2.5, size=n_neg)
    scores = np.concatenate([scores_pos, scores_neg])
    labels = np.concatenate([np.ones(n_pos, dtype=np.int), np.zeros(n_neg, dtype=np.int)])

    # Stratified cross-validation split
    skf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=seed)
    scores_folds = []
    labels_folds = []
    for ind_tr, ind_te in skf.split(scores[:, np.newaxis], labels):
        scores_folds.append(scores[ind_te])
        labels_folds.append(labels[ind_te])
        
    return scores_folds, labels_folds

# %%
seed = 123
np.random.seed(seed)
n_folds = 5
n_samples = 5000
n_pos = 2500
n_neg = 2500
loc = (3., -3.)

# %%
# Generate scores and labels
scores_folds, labels_folds = generate_score_data(loc, n_pos, n_neg, n_folds, seed)

# %%
# Calculating performance metrics for different proportion of positive samples
results_dict = metrics_varying_positive_class_proportion(scores_folds, labels_folds, seed=seed)
# Out:
# Performance metrics for target positive proportion: 0.0050
# Fold 1: Number of positive samples = 5. Target proportion = 0.0050. Actual proportion = 0.0050
# Fold 2: Number of positive samples = 5. Target proportion = 0.0050. Actual proportion = 0.0050
# Fold 3: Number of positive samples = 5. Target proportion = 0.0050. Actual proportion = 0.0050
# Fold 4: Number of positive samples = 5. Target proportion = 0.0050. Actual proportion = 0.0050
# Fold 5: Number of positive samples = 5. Target proportion = 0.0050. Actual proportion = 0.0050
# Area under the ROC curve = 0.965000
# Average precision = 0.505177
# Partial-AUC below fpr 0.0100 = 0.698492
# Partial-AUC below fpr 0.0500 = 0.798974
# Partial-AUC below fpr 0.1000 = 0.861053
# Partial-AUC below fpr 0.2000 = 0.902778
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.400000	0.001000	0.006000	0.066667
# 0.400000	0.005000	0.016000	0.125000
# 0.600000	0.010000	0.024000	0.250000
# 0.800000	0.050000	0.114000	0.350877
# 0.800000	0.100000	0.446000	0.179372
#
# Performance metrics for target positive proportion: 0.0600
# Fold 1: Number of positive samples = 60. Target proportion = 0.0600. Actual proportion = 0.0600
# Fold 2: Number of positive samples = 60. Target proportion = 0.0600. Actual proportion = 0.0600
# Fold 3: Number of positive samples = 60. Target proportion = 0.0600. Actual proportion = 0.0600
# Fold 4: Number of positive samples = 60. Target proportion = 0.0600. Actual proportion = 0.0600
# Fold 5: Number of positive samples = 60. Target proportion = 0.0600. Actual proportion = 0.0600
# Area under the ROC curve = 0.953200
# Average precision = 0.798750
# Partial-AUC below fpr 0.0100 = 0.710218
# Partial-AUC below fpr 0.0500 = 0.802564
# Partial-AUC below fpr 0.1000 = 0.852105
# Partial-AUC below fpr 0.2000 = 0.896389
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.350000	0.001000	0.002000	0.175000
# 0.433333	0.005000	0.006000	0.361111
# 0.500000	0.010000	0.010000	0.500000
# 0.766667	0.050000	0.052000	0.737179
# 0.866667	0.100000	0.106000	0.817610
#
# Performance metrics for target positive proportion: 0.1150
# Fold 1: Number of positive samples = 115. Target proportion = 0.1150. Actual proportion = 0.1150
# Fold 2: Number of positive samples = 115. Target proportion = 0.1150. Actual proportion = 0.1150
# Fold 3: Number of positive samples = 115. Target proportion = 0.1150. Actual proportion = 0.1150
# Fold 4: Number of positive samples = 115. Target proportion = 0.1150. Actual proportion = 0.1150
# Fold 5: Number of positive samples = 115. Target proportion = 0.1150. Actual proportion = 0.1150
# Area under the ROC curve = 0.952635
# Average precision = 0.861123
# Partial-AUC below fpr 0.0100 = 0.708106
# Partial-AUC below fpr 0.0500 = 0.802185
# Partial-AUC below fpr 0.1000 = 0.852494
# Partial-AUC below fpr 0.2000 = 0.896039
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.339130	0.001000	0.002000	0.169565
# 0.426087	0.005000	0.006000	0.355072
# 0.495652	0.010000	0.010000	0.495652
# 0.765217	0.050000	0.052000	0.735786
# 0.860870	0.100000	0.104000	0.827759
#
# Performance metrics for target positive proportion: 0.1700
# Fold 1: Number of positive samples = 170. Target proportion = 0.1700. Actual proportion = 0.1700
# Fold 2: Number of positive samples = 170. Target proportion = 0.1700. Actual proportion = 0.1700
# Fold 3: Number of positive samples = 170. Target proportion = 0.1700. Actual proportion = 0.1700
# Fold 4: Number of positive samples = 170. Target proportion = 0.1700. Actual proportion = 0.1700
# Fold 5: Number of positive samples = 170. Target proportion = 0.1700. Actual proportion = 0.1700
# Area under the ROC curve = 0.952665
# Average precision = 0.893668
# Partial-AUC below fpr 0.0100 = 0.710316
# Partial-AUC below fpr 0.0500 = 0.802534
# Partial-AUC below fpr 0.1000 = 0.851981
# Partial-AUC below fpr 0.2000 = 0.895408
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.341176	0.001000	0.002000	0.170588
# 0.429412	0.005000	0.006000	0.357843
# 0.494118	0.010000	0.010000	0.494118
# 0.764706	0.050000	0.050000	0.764706
# 0.858824	0.100000	0.102000	0.841984
#
# Performance metrics for target positive proportion: 0.2250
# Fold 1: Number of positive samples = 225. Target proportion = 0.2250. Actual proportion = 0.2250
# Fold 2: Number of positive samples = 225. Target proportion = 0.2250. Actual proportion = 0.2250
# Fold 3: Number of positive samples = 225. Target proportion = 0.2250. Actual proportion = 0.2250
# Fold 4: Number of positive samples = 225. Target proportion = 0.2250. Actual proportion = 0.2250
# Fold 5: Number of positive samples = 225. Target proportion = 0.2250. Actual proportion = 0.2250
# Area under the ROC curve = 0.952249
# Average precision = 0.912604
# Partial-AUC below fpr 0.0100 = 0.709659
# Partial-AUC below fpr 0.0500 = 0.802074
# Partial-AUC below fpr 0.1000 = 0.850667
# Partial-AUC below fpr 0.2000 = 0.894358
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.337778	0.001000	0.002000	0.168889
# 0.431111	0.005000	0.006000	0.359259
# 0.497778	0.010000	0.010000	0.497778
# 0.760000	0.050000	0.050000	0.760000
# 0.857778	0.100000	0.100000	0.857778
#
# Performance metrics for target positive proportion: 0.2800
# Fold 1: Number of positive samples = 280. Target proportion = 0.2800. Actual proportion = 0.2800
# Fold 2: Number of positive samples = 280. Target proportion = 0.2800. Actual proportion = 0.2800
# Fold 3: Number of positive samples = 280. Target proportion = 0.2800. Actual proportion = 0.2800
# Fold 4: Number of positive samples = 280. Target proportion = 0.2800. Actual proportion = 0.2800
# Fold 5: Number of positive samples = 280. Target proportion = 0.2800. Actual proportion = 0.2800
# Area under the ROC curve = 0.951957
# Average precision = 0.926167
# Partial-AUC below fpr 0.0100 = 0.710337
# Partial-AUC below fpr 0.0500 = 0.802711
# Partial-AUC below fpr 0.1000 = 0.851241
# Partial-AUC below fpr 0.2000 = 0.894563
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.339286	0.001000	0.002000	0.169643
# 0.428571	0.005000	0.006000	0.357143
# 0.500000	0.010000	0.010000	0.500000
# 0.764286	0.050000	0.050000	0.764286
# 0.857143	0.100000	0.100000	0.857143
#
# Performance metrics for target positive proportion: 0.3350
# Fold 1: Number of positive samples = 335. Target proportion = 0.3350. Actual proportion = 0.3350
# Fold 2: Number of positive samples = 335. Target proportion = 0.3350. Actual proportion = 0.3350
# Fold 3: Number of positive samples = 335. Target proportion = 0.3350. Actual proportion = 0.3350
# Fold 4: Number of positive samples = 335. Target proportion = 0.3350. Actual proportion = 0.3350
# Fold 5: Number of positive samples = 335. Target proportion = 0.3350. Actual proportion = 0.3350
# Area under the ROC curve = 0.950934
# Average precision = 0.934454
# Partial-AUC below fpr 0.0100 = 0.709593
# Partial-AUC below fpr 0.0500 = 0.801393
# Partial-AUC below fpr 0.1000 = 0.850024
# Partial-AUC below fpr 0.2000 = 0.893010
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.337313	0.001000	0.002000	0.168657
# 0.429851	0.005000	0.006000	0.358209
# 0.498507	0.010000	0.010000	0.498507
# 0.761194	0.050000	0.050000	0.761194
# 0.853731	0.100000	0.100000	0.853731
#
# Performance metrics for target positive proportion: 0.3900
# Fold 1: Number of positive samples = 390. Target proportion = 0.3900. Actual proportion = 0.3900
# Fold 2: Number of positive samples = 390. Target proportion = 0.3900. Actual proportion = 0.3900
# Fold 3: Number of positive samples = 390. Target proportion = 0.3900. Actual proportion = 0.3900
# Fold 4: Number of positive samples = 390. Target proportion = 0.3900. Actual proportion = 0.3900
# Fold 5: Number of positive samples = 390. Target proportion = 0.3900. Actual proportion = 0.3900
# Area under the ROC curve = 0.951182
# Average precision = 0.942624
# Partial-AUC below fpr 0.0100 = 0.708285
# Partial-AUC below fpr 0.0500 = 0.801604
# Partial-AUC below fpr 0.1000 = 0.850418
# Partial-AUC below fpr 0.2000 = 0.894131
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.338462	0.001000	0.002000	0.169231
# 0.428205	0.005000	0.006000	0.356838
# 0.497436	0.010000	0.010000	0.497436
# 0.761538	0.050000	0.050000	0.761538
# 0.856410	0.100000	0.100000	0.856410
#
# Performance metrics for target positive proportion: 0.4450
# Fold 1: Number of positive samples = 445. Target proportion = 0.4450. Actual proportion = 0.4450
# Fold 2: Number of positive samples = 445. Target proportion = 0.4450. Actual proportion = 0.4450
# Fold 3: Number of positive samples = 445. Target proportion = 0.4450. Actual proportion = 0.4450
# Fold 4: Number of positive samples = 445. Target proportion = 0.4450. Actual proportion = 0.4450
# Fold 5: Number of positive samples = 445. Target proportion = 0.4450. Actual proportion = 0.4450
# Area under the ROC curve = 0.951191
# Average precision = 0.948393
# Partial-AUC below fpr 0.0100 = 0.707752
# Partial-AUC below fpr 0.0500 = 0.801441
# Partial-AUC below fpr 0.1000 = 0.850266
# Partial-AUC below fpr 0.2000 = 0.893670
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.337079	0.001000	0.002000	0.168539
# 0.426966	0.005000	0.006000	0.355805
# 0.501124	0.010000	0.010000	0.501124
# 0.762921	0.050000	0.050000	0.762921
# 0.853933	0.100000	0.100000	0.853933
#
# Performance metrics for target positive proportion: 0.5000
# Fold 1: Number of positive samples = 500. Target proportion = 0.5000. Actual proportion = 0.5000
# Fold 2: Number of positive samples = 500. Target proportion = 0.5000. Actual proportion = 0.5000
# Fold 3: Number of positive samples = 500. Target proportion = 0.5000. Actual proportion = 0.5000
# Fold 4: Number of positive samples = 500. Target proportion = 0.5000. Actual proportion = 0.5000
# Fold 5: Number of positive samples = 500. Target proportion = 0.5000. Actual proportion = 0.5000
# Area under the ROC curve = 0.951232
# Average precision = 0.953300
# Partial-AUC below fpr 0.0100 = 0.707739
# Partial-AUC below fpr 0.0500 = 0.801436
# Partial-AUC below fpr 0.1000 = 0.850989
# Partial-AUC below fpr 0.2000 = 0.893756
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.338000	0.001000	0.002000	0.169000
# 0.430000	0.005000	0.006000	0.358333
# 0.506000	0.010000	0.010000	0.506000
# 0.764000	0.050000	0.050000	0.764000
# 0.854000	0.100000	0.100000	0.854000

# %%
pprint(results_dict, indent=1)
# Out:
# {'auc': {'CI_lower': [0.83735,
#                       0.9243741666666667,
#                       0.9340669565217391,
#                       0.9379691176470588,
#                       0.9400591111111112,
#                       0.9420962500000001,
#                       0.9436158208955223,
#                       0.9443570512820513,
#                       0.9457259550561796,
#                       0.9477956000000001],
#          'CI_upper': [0.99802,
#                       0.9746083333333333,
#                       0.9689573913043479,
#                       0.9673370588235295,
#                       0.9671180000000001,
#                       0.9653844642857143,
#                       0.9650849253731344,
#                       0.9643349999999999,
#                       0.9629482022471909,
#                       0.9608639999999999],
#          'median': [0.9650000000000001,
#                     0.9532,
#                     0.9526347826086956,
#                     0.952664705882353,
#                     0.9522488888888889,
#                     0.9519571428571428,
#                     0.9509343283582089,
#                     0.9511820512820512,
#                     0.9511910112359552,
#                     0.951232]},
#  'avg_prec': {'CI_lower': [0.12260291527339884,
#                            0.7282150058726247,
#                            0.8225126724085954,
#                            0.8678460871367486,
#                            0.8949202174989459,
#                            0.9124893289836541,
#                            0.9259487839159598,
#                            0.9345851072452654,
#                            0.9425223620621905,
#                            0.9496974920255923],
#               'CI_upper': [0.8761904761904762,
#                            0.8568715607122288,
#                            0.8956531987799283,
#                            0.919342442250776,
#                            0.9322667449382046,
#                            0.942821006447172,
#                            0.9492059758173831,
#                            0.9548898862837547,
#                            0.958277545739988,
#                            0.9606680363975767],
#               'median': [0.5051766513056836,
#                          0.7987499716293441,
#                          0.8611231646876478,
#                          0.893667995007646,
#                          0.9126042788641658,
#                          0.9261672371080918,
#                          0.9344541941593447,
#                          0.9426235203847702,
#                          0.948393442850243,
#                          0.9533002829576005]},
#  'fpr': {'CI_lower': [array([0.002  , 0.006  , 0.01   , 0.05   , 0.10095]),
#                       array([0.002, 0.006, 0.01 , 0.05 , 0.1  ]),
#                       array([0.002, 0.006, 0.01 , 0.05 , 0.1  ]),
#                       array([0.002, 0.006, 0.01 , 0.05 , 0.1  ]),
#                       array([0.002, 0.006, 0.01 , 0.05 , 0.1  ]),
#                       array([0.002, 0.006, 0.01 , 0.05 , 0.1  ]),
#                       array([0.002, 0.006, 0.01 , 0.05 , 0.1  ]),
#                       array([0.002, 0.006, 0.01 , 0.05 , 0.1  ]),
#                       array([0.002, 0.006, 0.01 , 0.05 , 0.1  ]),
#                       array([0.002, 0.006, 0.01 , 0.05 , 0.1  ])],
#          'CI_upper': [array([0.106  , 0.73495, 1.     , 1.     , 1.     ]),
#                       array([0.004, 0.014, 0.016, 0.072, 0.162]),
#                       array([0.004  , 0.01105, 0.014  , 0.056  , 0.12   ]),
#                       array([0.004, 0.008, 0.012, 0.056, 0.11 ]),
#                       array([0.004, 0.006, 0.012, 0.054, 0.108]),
#                       array([0.004, 0.006, 0.012, 0.054, 0.108]),
#                       array([0.004, 0.006, 0.012, 0.054, 0.108]),
#                       array([0.004, 0.006, 0.012, 0.054, 0.108]),
#                       array([0.004, 0.006, 0.012, 0.052, 0.108]),
#                       array([0.002 , 0.006 , 0.0118, 0.0518, 0.1072])],
#          'median': [array([0.006, 0.016, 0.024, 0.114, 0.446]),
#                     array([0.002, 0.006, 0.01 , 0.052, 0.106]),
#                     array([0.002, 0.006, 0.01 , 0.052, 0.104]),
#                     array([0.002, 0.006, 0.01 , 0.05 , 0.102]),
#                     array([0.002, 0.006, 0.01 , 0.05 , 0.1  ]),
#                     array([0.002, 0.006, 0.01 , 0.05 , 0.1  ]),
#                     array([0.002, 0.006, 0.01 , 0.05 , 0.1  ]),
#                     array([0.002, 0.006, 0.01 , 0.05 , 0.1  ]),
#                     array([0.002, 0.006, 0.01 , 0.05 , 0.1  ]),
#                     array([0.002, 0.006, 0.01 , 0.05 , 0.1  ])]},
#  'pauc': {'CI_lower': [array([0.49748744, 0.59169231, 0.64521053, 0.72877778]),
#                        array([0.65661642, 0.74922222, 0.80385965, 0.85158102]),
#                        array([0.67140048, 0.76300111, 0.81587414, 0.86392633]),
#                        array([0.67957434, 0.7693997 , 0.82087771, 0.86833007]),
#                        array([0.68619765, 0.77442735, 0.82602456, 0.87336975]),
#                        array([0.68681802, 0.77940659, 0.82984586, 0.8750997 ]),
#                        array([0.69113478, 0.78101799, 0.83069442, 0.87689594]),
#                        array([0.69282309, 0.78226561, 0.83207625, 0.87717593]),
#                        array([0.69554514, 0.78403688, 0.83340331, 0.87971567]),
#                        array([0.70098492, 0.7899241 , 0.83875579, 0.88369333])],
#           'CI_upper': [array([0.91005025, 0.97969231, 0.98957895, 0.9945    ]),
#                        array([0.77386935, 0.85164103, 0.89685088, 0.93412731]),
#                        array([0.76362246, 0.83859978, 0.88421968, 0.92499758]),
#                        array([0.74668933, 0.8334902 , 0.88225697, 0.9223317 ]),
#                        array([0.74428811, 0.82637265, 0.87668772, 0.91991358]),
#                        array([0.74301866, 0.82568681, 0.87558741, 0.91761359]),
#                        array([0.73765094, 0.82225488, 0.87228437, 0.91582753]),
#                        array([0.73585878, 0.82017357, 0.87125911, 0.91470584]),
#                        array([0.73361753, 0.81865745, 0.86984565, 0.91308427]),
#                        array([0.72832161, 0.81393231, 0.86497684, 0.90925111])],
#           'median': [array([0.69849246, 0.79897436, 0.86105263, 0.90277778]),
#                      array([0.71021776, 0.8025641 , 0.85210526, 0.89638889]),
#                      array([0.70810575, 0.80218506, 0.85249428, 0.89603865]),
#                      array([0.71031629, 0.80253394, 0.85198142, 0.8954085 ]),
#                      array([0.70965941, 0.80207407, 0.85066667, 0.89435802]),
#                      array([0.7103374 , 0.80271062, 0.8512406 , 0.89456349]),
#                      array([0.70959274, 0.80139303, 0.85002357, 0.89300995]),
#                      array([0.70828501, 0.80160421, 0.85041835, 0.89413105]),
#                      array([0.70775224, 0.80144051, 0.85026611, 0.89367041]),
#                      array([0.70773869, 0.8014359 , 0.85098947, 0.89375556])]},
#  'proportion': array([0.005, 0.06 , 0.115, 0.17 , 0.225, 0.28 , 0.335, 0.39 , 0.445,
#        0.5  ]),
#  'tpr': {'CI_lower': [array([0. , 0. , 0. , 0.4, 0.4]),
#                       array([0.21666667, 0.31666667, 0.38333333, 0.64125   , 0.76666667]),
#                       array([0.25217391, 0.34782609, 0.40413043, 0.66956522, 0.8       ]),
#                       array([0.26470588, 0.35882353, 0.42352941, 0.68235294, 0.81176471]),
#                       array([0.28      , 0.37333333, 0.44      , 0.68888889, 0.81333333]),
#                       array([0.28214286, 0.37142857, 0.43928571, 0.69642857, 0.82142857]),
#                       array([0.285     , 0.37910448, 0.44477612, 0.69552239, 0.82686567]),
#                       array([0.28205128, 0.38461538, 0.45128205, 0.7025641 , 0.82820513]),
#                       array([0.28988764, 0.39101124, 0.45842697, 0.70561798, 0.83370787]),
#                       array([0.3016, 0.402 , 0.468 , 0.7172, 0.8412])],
#          'CI_upper': [array([0.8  , 0.905, 1.   , 1.   , 1.   ]),
#                       array([0.48333333, 0.56666667, 0.61666667, 0.87541667, 0.93333333]),
#                       array([0.45217391, 0.53913043, 0.59130435, 0.84347826, 0.92173913]),
#                       array([0.43529412, 0.51176471, 0.56470588, 0.83529412, 0.91176471]),
#                       array([0.43111111, 0.50666667, 0.55111111, 0.82666667, 0.90666667]),
#                       array([0.42857143, 0.501875  , 0.54642857, 0.81973214, 0.90357143]),
#                       array([0.42089552, 0.48955224, 0.53731343, 0.81350746, 0.89850746]),
#                       array([0.41282051, 0.48852564, 0.52955128, 0.81160256, 0.89487179]),
#                       array([0.41123596, 0.48314607, 0.52134831, 0.80674157, 0.89213483]),
#                       array([0.396 , 0.4716, 0.5116, 0.7978, 0.8852])],
#          'median': [array([0.4, 0.4, 0.6, 0.8, 0.8]),
#                     array([0.35      , 0.43333333, 0.5       , 0.76666667, 0.86666667]),
#                     array([0.33913043, 0.42608696, 0.49565217, 0.76521739, 0.86086957]),
#                     array([0.34117647, 0.42941176, 0.49411765, 0.76470588, 0.85882353]),
#                     array([0.33777778, 0.43111111, 0.49777778, 0.76      , 0.85777778]),
#                     array([0.33928571, 0.42857143, 0.5       , 0.76428571, 0.85714286]),
#                     array([0.33731343, 0.42985075, 0.49850746, 0.76119403, 0.85373134]),
#                     array([0.33846154, 0.42820513, 0.4974359 , 0.76153846, 0.85641026]),
#                     array([0.33707865, 0.42696629, 0.5011236 , 0.76292135, 0.85393258]),
#                     array([0.338, 0.43 , 0.506, 0.764, 0.854])]}}

# %% [markdown]
# ### Plotting the performance metrics for different methods as a function of positive class proportion

# %%
output_dir = '/Users/jayaram/Documents/temp'
methods = ['method1', 'method2', 'method3']
locs = [(3, -3), (2, -3), (2, -2)]

# %%
results = dict()
j = 0
for m in methods:
    scores_folds, labels_folds = generate_score_data(locs[j], n_pos, n_neg, n_folds, seed)
    f = os.path.join(output_dir, 'results_{}.pkl'.format(m))
    results[m] = metrics_varying_positive_class_proportion(scores_folds, labels_folds, seed=seed, output_file=f)
    j += 1
# Out:
# Performance metrics for target positive proportion: 0.0050
# Fold 1: Number of positive samples = 5. Target proportion = 0.0050. Actual proportion = 0.0050
# Fold 2: Number of positive samples = 5. Target proportion = 0.0050. Actual proportion = 0.0050
# Fold 3: Number of positive samples = 5. Target proportion = 0.0050. Actual proportion = 0.0050
# Fold 4: Number of positive samples = 5. Target proportion = 0.0050. Actual proportion = 0.0050
# Fold 5: Number of positive samples = 5. Target proportion = 0.0050. Actual proportion = 0.0050
# Area under the ROC curve = 0.961200
# Average precision = 0.439961
# Partial-AUC below fpr 0.0100 = 0.678392
# Partial-AUC below fpr 0.0500 = 0.790769
# Partial-AUC below fpr 0.1000 = 0.850526
# Partial-AUC below fpr 0.2000 = 0.892222
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.200000	0.001000	0.002000	0.100000
# 0.400000	0.005000	0.014000	0.142857
# 0.400000	0.010000	0.020000	0.200000
# 0.800000	0.050000	0.128000	0.312500
# 0.800000	0.100000	0.448000	0.178571
#
# Performance metrics for target positive proportion: 0.0600
# Fold 1: Number of positive samples = 60. Target proportion = 0.0600. Actual proportion = 0.0600
# Fold 2: Number of positive samples = 60. Target proportion = 0.0600. Actual proportion = 0.0600
# Fold 3: Number of positive samples = 60. Target proportion = 0.0600. Actual proportion = 0.0600
# Fold 4: Number of positive samples = 60. Target proportion = 0.0600. Actual proportion = 0.0600
# Fold 5: Number of positive samples = 60. Target proportion = 0.0600. Actual proportion = 0.0600
# Area under the ROC curve = 0.951683
# Average precision = 0.775312
# Partial-AUC below fpr 0.0100 = 0.680905
# Partial-AUC below fpr 0.0500 = 0.791111
# Partial-AUC below fpr 0.1000 = 0.846053
# Partial-AUC below fpr 0.2000 = 0.892407
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.200000	0.001000	0.002000	0.100000
# 0.383333	0.005000	0.006000	0.319444
# 0.450000	0.010000	0.010000	0.450000
# 0.766667	0.050000	0.054000	0.709877
# 0.866667	0.100000	0.108000	0.802469
#
# Performance metrics for target positive proportion: 0.1150
# Fold 1: Number of positive samples = 115. Target proportion = 0.1150. Actual proportion = 0.1150
# Fold 2: Number of positive samples = 115. Target proportion = 0.1150. Actual proportion = 0.1150
# Fold 3: Number of positive samples = 115. Target proportion = 0.1150. Actual proportion = 0.1150
# Fold 4: Number of positive samples = 115. Target proportion = 0.1150. Actual proportion = 0.1150
# Fold 5: Number of positive samples = 115. Target proportion = 0.1150. Actual proportion = 0.1150
# Area under the ROC curve = 0.950913
# Average precision = 0.850705
# Partial-AUC below fpr 0.0100 = 0.682762
# Partial-AUC below fpr 0.0500 = 0.793356
# Partial-AUC below fpr 0.1000 = 0.846453
# Partial-AUC below fpr 0.2000 = 0.893744
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.200000	0.001000	0.002000	0.100000
# 0.382609	0.005000	0.006000	0.318841
# 0.452174	0.010000	0.010000	0.452174
# 0.765217	0.050000	0.054000	0.708535
# 0.860870	0.100000	0.106000	0.812141
#
# Performance metrics for target positive proportion: 0.1700
# Fold 1: Number of positive samples = 170. Target proportion = 0.1700. Actual proportion = 0.1700
# Fold 2: Number of positive samples = 170. Target proportion = 0.1700. Actual proportion = 0.1700
# Fold 3: Number of positive samples = 170. Target proportion = 0.1700. Actual proportion = 0.1700
# Fold 4: Number of positive samples = 170. Target proportion = 0.1700. Actual proportion = 0.1700
# Fold 5: Number of positive samples = 170. Target proportion = 0.1700. Actual proportion = 0.1700
# Area under the ROC curve = 0.950894
# Average precision = 0.884268
# Partial-AUC below fpr 0.0100 = 0.680757
# Partial-AUC below fpr 0.0500 = 0.792640
# Partial-AUC below fpr 0.1000 = 0.845882
# Partial-AUC below fpr 0.2000 = 0.891748
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.194118	0.001000	0.002000	0.097059
# 0.376471	0.005000	0.006000	0.313725
# 0.441176	0.010000	0.010000	0.441176
# 0.764706	0.050000	0.052000	0.735294
# 0.858824	0.100000	0.100000	0.858824
#
# Performance metrics for target positive proportion: 0.2250
# Fold 1: Number of positive samples = 225. Target proportion = 0.2250. Actual proportion = 0.2250
# Fold 2: Number of positive samples = 225. Target proportion = 0.2250. Actual proportion = 0.2250
# Fold 3: Number of positive samples = 225. Target proportion = 0.2250. Actual proportion = 0.2250
# Fold 4: Number of positive samples = 225. Target proportion = 0.2250. Actual proportion = 0.2250
# Fold 5: Number of positive samples = 225. Target proportion = 0.2250. Actual proportion = 0.2250
# Area under the ROC curve = 0.951138
# Average precision = 0.906538
# Partial-AUC below fpr 0.0100 = 0.683082
# Partial-AUC below fpr 0.0500 = 0.793778
# Partial-AUC below fpr 0.1000 = 0.847041
# Partial-AUC below fpr 0.2000 = 0.891778
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.191111	0.001000	0.002000	0.095556
# 0.377778	0.005000	0.006000	0.314815
# 0.448889	0.010000	0.010000	0.448889
# 0.773333	0.050000	0.052000	0.743590
# 0.860000	0.100000	0.100000	0.860000
#
# Performance metrics for target positive proportion: 0.2800
# Fold 1: Number of positive samples = 280. Target proportion = 0.2800. Actual proportion = 0.2800
# Fold 2: Number of positive samples = 280. Target proportion = 0.2800. Actual proportion = 0.2800
# Fold 3: Number of positive samples = 280. Target proportion = 0.2800. Actual proportion = 0.2800
# Fold 4: Number of positive samples = 280. Target proportion = 0.2800. Actual proportion = 0.2800
# Fold 5: Number of positive samples = 280. Target proportion = 0.2800. Actual proportion = 0.2800
# Area under the ROC curve = 0.951321
# Average precision = 0.921174
# Partial-AUC below fpr 0.0100 = 0.683417
# Partial-AUC below fpr 0.0500 = 0.793553
# Partial-AUC below fpr 0.1000 = 0.847199
# Partial-AUC below fpr 0.2000 = 0.892054
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.185714	0.001000	0.002000	0.092857
# 0.378571	0.005000	0.006000	0.315476
# 0.451786	0.010000	0.010000	0.451786
# 0.767857	0.050000	0.050000	0.767857
# 0.860714	0.100000	0.100000	0.860714
#
# Performance metrics for target positive proportion: 0.3350
# Fold 1: Number of positive samples = 335. Target proportion = 0.3350. Actual proportion = 0.3350
# Fold 2: Number of positive samples = 335. Target proportion = 0.3350. Actual proportion = 0.3350
# Fold 3: Number of positive samples = 335. Target proportion = 0.3350. Actual proportion = 0.3350
# Fold 4: Number of positive samples = 335. Target proportion = 0.3350. Actual proportion = 0.3350
# Fold 5: Number of positive samples = 335. Target proportion = 0.3350. Actual proportion = 0.3350
# Area under the ROC curve = 0.950976
# Average precision = 0.931330
# Partial-AUC below fpr 0.0100 = 0.682892
# Partial-AUC below fpr 0.0500 = 0.794168
# Partial-AUC below fpr 0.1000 = 0.846599
# Partial-AUC below fpr 0.2000 = 0.891219
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.185075	0.001000	0.002000	0.092537
# 0.376119	0.005000	0.006000	0.313433
# 0.453731	0.010000	0.010000	0.453731
# 0.770149	0.050000	0.050000	0.770149
# 0.859701	0.100000	0.100000	0.859701
#
# Performance metrics for target positive proportion: 0.3900
# Fold 1: Number of positive samples = 390. Target proportion = 0.3900. Actual proportion = 0.3900
# Fold 2: Number of positive samples = 390. Target proportion = 0.3900. Actual proportion = 0.3900
# Fold 3: Number of positive samples = 390. Target proportion = 0.3900. Actual proportion = 0.3900
# Fold 4: Number of positive samples = 390. Target proportion = 0.3900. Actual proportion = 0.3900
# Fold 5: Number of positive samples = 390. Target proportion = 0.3900. Actual proportion = 0.3900
# Area under the ROC curve = 0.951041
# Average precision = 0.939177
# Partial-AUC below fpr 0.0100 = 0.682515
# Partial-AUC below fpr 0.0500 = 0.794083
# Partial-AUC below fpr 0.1000 = 0.846653
# Partial-AUC below fpr 0.2000 = 0.891382
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.182051	0.001000	0.002000	0.091026
# 0.376923	0.005000	0.006000	0.314103
# 0.456410	0.010000	0.010000	0.456410
# 0.771795	0.050000	0.050000	0.771795
# 0.861538	0.100000	0.100000	0.861538
#
# Performance metrics for target positive proportion: 0.4450
# Fold 1: Number of positive samples = 445. Target proportion = 0.4450. Actual proportion = 0.4450
# Fold 2: Number of positive samples = 445. Target proportion = 0.4450. Actual proportion = 0.4450
# Fold 3: Number of positive samples = 445. Target proportion = 0.4450. Actual proportion = 0.4450
# Fold 4: Number of positive samples = 445. Target proportion = 0.4450. Actual proportion = 0.4450
# Fold 5: Number of positive samples = 445. Target proportion = 0.4450. Actual proportion = 0.4450
# Area under the ROC curve = 0.951193
# Average precision = 0.945334
# Partial-AUC below fpr 0.0100 = 0.683248
# Partial-AUC below fpr 0.0500 = 0.793535
# Partial-AUC below fpr 0.1000 = 0.847309
# Partial-AUC below fpr 0.2000 = 0.890911
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.182022	0.001000	0.002000	0.091011
# 0.373034	0.005000	0.006000	0.310861
# 0.458427	0.010000	0.010000	0.458427
# 0.773034	0.050000	0.050000	0.773034
# 0.858427	0.100000	0.100000	0.858427
#
# Performance metrics for target positive proportion: 0.5000
# Fold 1: Number of positive samples = 500. Target proportion = 0.5000. Actual proportion = 0.5000
# Fold 2: Number of positive samples = 500. Target proportion = 0.5000. Actual proportion = 0.5000
# Fold 3: Number of positive samples = 500. Target proportion = 0.5000. Actual proportion = 0.5000
# Fold 4: Number of positive samples = 500. Target proportion = 0.5000. Actual proportion = 0.5000
# Fold 5: Number of positive samples = 500. Target proportion = 0.5000. Actual proportion = 0.5000
# Area under the ROC curve = 0.950716
# Average precision = 0.949513
# Partial-AUC below fpr 0.0100 = 0.683216
# Partial-AUC below fpr 0.0500 = 0.793395
# Partial-AUC below fpr 0.1000 = 0.848253
# Partial-AUC below fpr 0.2000 = 0.891044
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.180000	0.001000	0.002000	0.090000
# 0.372000	0.005000	0.006000	0.310000
# 0.460000	0.010000	0.010000	0.460000
# 0.772000	0.050000	0.050000	0.772000
# 0.858000	0.100000	0.100000	0.858000
#
# Performance metrics for target positive proportion: 0.0050
# Fold 1: Number of positive samples = 5. Target proportion = 0.0050. Actual proportion = 0.0050
# Fold 2: Number of positive samples = 5. Target proportion = 0.0050. Actual proportion = 0.0050
# Fold 3: Number of positive samples = 5. Target proportion = 0.0050. Actual proportion = 0.0050
# Fold 4: Number of positive samples = 5. Target proportion = 0.0050. Actual proportion = 0.0050
# Fold 5: Number of positive samples = 5. Target proportion = 0.0050. Actual proportion = 0.0050
# Area under the ROC curve = 0.926600
# Average precision = 0.282399
# Partial-AUC below fpr 0.0100 = 0.597990
# Partial-AUC below fpr 0.0500 = 0.712821
# Partial-AUC below fpr 0.1000 = 0.777895
# Partial-AUC below fpr 0.2000 = 0.837778
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.000000	0.001000	0.002000	0.000000
# 0.200000	0.005000	0.014000	0.071429
# 0.200000	0.010000	0.019000	0.105263
# 0.600000	0.050000	0.100000	0.300000
# 0.800000	0.100000	0.232000	0.344828
#
# Performance metrics for target positive proportion: 0.0600
# Fold 1: Number of positive samples = 60. Target proportion = 0.0600. Actual proportion = 0.0600
# Fold 2: Number of positive samples = 60. Target proportion = 0.0600. Actual proportion = 0.0600
# Fold 3: Number of positive samples = 60. Target proportion = 0.0600. Actual proportion = 0.0600
# Fold 4: Number of positive samples = 60. Target proportion = 0.0600. Actual proportion = 0.0600
# Fold 5: Number of positive samples = 60. Target proportion = 0.0600. Actual proportion = 0.0600
# Area under the ROC curve = 0.916933
# Average precision = 0.655798
# Partial-AUC below fpr 0.0100 = 0.614740
# Partial-AUC below fpr 0.0500 = 0.716068
# Partial-AUC below fpr 0.1000 = 0.776316
# Partial-AUC below fpr 0.2000 = 0.834120
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.100000	0.001000	0.002000	0.050000
# 0.250000	0.005000	0.008000	0.156250
# 0.300000	0.010000	0.010000	0.300000
# 0.633333	0.050000	0.054000	0.586420
# 0.766667	0.100000	0.106000	0.723270
#
# Performance metrics for target positive proportion: 0.1150
# Fold 1: Number of positive samples = 115. Target proportion = 0.1150. Actual proportion = 0.1150
# Fold 2: Number of positive samples = 115. Target proportion = 0.1150. Actual proportion = 0.1150
# Fold 3: Number of positive samples = 115. Target proportion = 0.1150. Actual proportion = 0.1150
# Fold 4: Number of positive samples = 115. Target proportion = 0.1150. Actual proportion = 0.1150
# Fold 5: Number of positive samples = 115. Target proportion = 0.1150. Actual proportion = 0.1150
# Area under the ROC curve = 0.916722
# Average precision = 0.760625
# Partial-AUC below fpr 0.0100 = 0.615469
# Partial-AUC below fpr 0.0500 = 0.717191
# Partial-AUC below fpr 0.1000 = 0.775789
# Partial-AUC below fpr 0.2000 = 0.834179
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.104348	0.001000	0.002000	0.052174
# 0.247826	0.005000	0.006000	0.206522
# 0.304348	0.010000	0.010000	0.304348
# 0.626087	0.050000	0.052000	0.602007
# 0.765217	0.100000	0.104000	0.735786
#
# Performance metrics for target positive proportion: 0.1700
# Fold 1: Number of positive samples = 170. Target proportion = 0.1700. Actual proportion = 0.1700
# Fold 2: Number of positive samples = 170. Target proportion = 0.1700. Actual proportion = 0.1700
# Fold 3: Number of positive samples = 170. Target proportion = 0.1700. Actual proportion = 0.1700
# Fold 4: Number of positive samples = 170. Target proportion = 0.1700. Actual proportion = 0.1700
# Fold 5: Number of positive samples = 170. Target proportion = 0.1700. Actual proportion = 0.1700
# Area under the ROC curve = 0.916376
# Average precision = 0.810990
# Partial-AUC below fpr 0.0100 = 0.617795
# Partial-AUC below fpr 0.0500 = 0.717526
# Partial-AUC below fpr 0.1000 = 0.775851
# Partial-AUC below fpr 0.2000 = 0.832369
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.100000	0.001000	0.002000	0.050000
# 0.247059	0.005000	0.006000	0.205882
# 0.300000	0.010000	0.010000	0.300000
# 0.635294	0.050000	0.050000	0.635294
# 0.755882	0.100000	0.102000	0.741061
#
# Performance metrics for target positive proportion: 0.2250
# Fold 1: Number of positive samples = 225. Target proportion = 0.2250. Actual proportion = 0.2250
# Fold 2: Number of positive samples = 225. Target proportion = 0.2250. Actual proportion = 0.2250
# Fold 3: Number of positive samples = 225. Target proportion = 0.2250. Actual proportion = 0.2250
# Fold 4: Number of positive samples = 225. Target proportion = 0.2250. Actual proportion = 0.2250
# Fold 5: Number of positive samples = 225. Target proportion = 0.2250. Actual proportion = 0.2250
# Area under the ROC curve = 0.916662
# Average precision = 0.844797
# Partial-AUC below fpr 0.0100 = 0.616974
# Partial-AUC below fpr 0.0500 = 0.720160
# Partial-AUC below fpr 0.1000 = 0.776632
# Partial-AUC below fpr 0.2000 = 0.833358
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.102222	0.001000	0.002000	0.051111
# 0.244444	0.005000	0.006000	0.203704
# 0.302222	0.010000	0.010000	0.302222
# 0.635556	0.050000	0.050000	0.635556
# 0.755556	0.100000	0.100000	0.755556
#
# Performance metrics for target positive proportion: 0.2800
# Fold 1: Number of positive samples = 280. Target proportion = 0.2800. Actual proportion = 0.2800
# Fold 2: Number of positive samples = 280. Target proportion = 0.2800. Actual proportion = 0.2800
# Fold 3: Number of positive samples = 280. Target proportion = 0.2800. Actual proportion = 0.2800
# Fold 4: Number of positive samples = 280. Target proportion = 0.2800. Actual proportion = 0.2800
# Fold 5: Number of positive samples = 280. Target proportion = 0.2800. Actual proportion = 0.2800
# Area under the ROC curve = 0.917211
# Average precision = 0.867604
# Partial-AUC below fpr 0.0100 = 0.616834
# Partial-AUC below fpr 0.0500 = 0.719487
# Partial-AUC below fpr 0.1000 = 0.776053
# Partial-AUC below fpr 0.2000 = 0.832917
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.100000	0.001000	0.002000	0.050000
# 0.246429	0.005000	0.006000	0.205357
# 0.300000	0.010000	0.010000	0.300000
# 0.632143	0.050000	0.050000	0.632143
# 0.757143	0.100000	0.100000	0.757143
#
# Performance metrics for target positive proportion: 0.3350
# Fold 1: Number of positive samples = 335. Target proportion = 0.3350. Actual proportion = 0.3350
# Fold 2: Number of positive samples = 335. Target proportion = 0.3350. Actual proportion = 0.3350
# Fold 3: Number of positive samples = 335. Target proportion = 0.3350. Actual proportion = 0.3350
# Fold 4: Number of positive samples = 335. Target proportion = 0.3350. Actual proportion = 0.3350
# Fold 5: Number of positive samples = 335. Target proportion = 0.3350. Actual proportion = 0.3350
# Area under the ROC curve = 0.916499
# Average precision = 0.883977
# Partial-AUC below fpr 0.0100 = 0.617340
# Partial-AUC below fpr 0.0500 = 0.720046
# Partial-AUC below fpr 0.1000 = 0.776355
# Partial-AUC below fpr 0.2000 = 0.832430
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.104478	0.001000	0.002000	0.052239
# 0.244776	0.005000	0.006000	0.203980
# 0.298507	0.010000	0.010000	0.298507
# 0.635821	0.050000	0.050000	0.635821
# 0.755224	0.100000	0.100000	0.755224
#
# Performance metrics for target positive proportion: 0.3900
# Fold 1: Number of positive samples = 390. Target proportion = 0.3900. Actual proportion = 0.3900
# Fold 2: Number of positive samples = 390. Target proportion = 0.3900. Actual proportion = 0.3900
# Fold 3: Number of positive samples = 390. Target proportion = 0.3900. Actual proportion = 0.3900
# Fold 4: Number of positive samples = 390. Target proportion = 0.3900. Actual proportion = 0.3900
# Fold 5: Number of positive samples = 390. Target proportion = 0.3900. Actual proportion = 0.3900
# Area under the ROC curve = 0.916721
# Average precision = 0.896345
# Partial-AUC below fpr 0.0100 = 0.617575
# Partial-AUC below fpr 0.0500 = 0.720999
# Partial-AUC below fpr 0.1000 = 0.776451
# Partial-AUC below fpr 0.2000 = 0.832614
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.102564	0.001000	0.002000	0.051282
# 0.243590	0.005000	0.006000	0.202991
# 0.297436	0.010000	0.010000	0.297436
# 0.638462	0.050000	0.050000	0.638462
# 0.753846	0.100000	0.100000	0.753846
#
# Performance metrics for target positive proportion: 0.4450
# Fold 1: Number of positive samples = 445. Target proportion = 0.4450. Actual proportion = 0.4450
# Fold 2: Number of positive samples = 445. Target proportion = 0.4450. Actual proportion = 0.4450
# Fold 3: Number of positive samples = 445. Target proportion = 0.4450. Actual proportion = 0.4450
# Fold 4: Number of positive samples = 445. Target proportion = 0.4450. Actual proportion = 0.4450
# Fold 5: Number of positive samples = 445. Target proportion = 0.4450. Actual proportion = 0.4450
# Area under the ROC curve = 0.916519
# Average precision = 0.906215
# Partial-AUC below fpr 0.0100 = 0.617526
# Partial-AUC below fpr 0.0500 = 0.721233
# Partial-AUC below fpr 0.1000 = 0.775494
# Partial-AUC below fpr 0.2000 = 0.831592
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.105618	0.001000	0.002000	0.052809
# 0.242697	0.005000	0.006000	0.202247
# 0.296629	0.010000	0.010000	0.296629
# 0.638202	0.050000	0.050000	0.638202
# 0.752809	0.100000	0.100000	0.752809
#
# Performance metrics for target positive proportion: 0.5000
# Fold 1: Number of positive samples = 500. Target proportion = 0.5000. Actual proportion = 0.5000
# Fold 2: Number of positive samples = 500. Target proportion = 0.5000. Actual proportion = 0.5000
# Fold 3: Number of positive samples = 500. Target proportion = 0.5000. Actual proportion = 0.5000
# Fold 4: Number of positive samples = 500. Target proportion = 0.5000. Actual proportion = 0.5000
# Fold 5: Number of positive samples = 500. Target proportion = 0.5000. Actual proportion = 0.5000
# Area under the ROC curve = 0.916224
# Average precision = 0.913546
# Partial-AUC below fpr 0.0100 = 0.616080
# Partial-AUC below fpr 0.0500 = 0.721108
# Partial-AUC below fpr 0.1000 = 0.775453
# Partial-AUC below fpr 0.2000 = 0.830556
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.104000	0.001000	0.002000	0.052000
# 0.238000	0.005000	0.006000	0.198333
# 0.296000	0.010000	0.010000	0.296000
# 0.644000	0.050000	0.050000	0.644000
# 0.750000	0.100000	0.100000	0.750000
#
# Performance metrics for target positive proportion: 0.0050
# Fold 1: Number of positive samples = 5. Target proportion = 0.0050. Actual proportion = 0.0050
# Fold 2: Number of positive samples = 5. Target proportion = 0.0050. Actual proportion = 0.0050
# Fold 3: Number of positive samples = 5. Target proportion = 0.0050. Actual proportion = 0.0050
# Fold 4: Number of positive samples = 5. Target proportion = 0.0050. Actual proportion = 0.0050
# Fold 5: Number of positive samples = 5. Target proportion = 0.0050. Actual proportion = 0.0050
# Area under the ROC curve = 0.873200
# Average precision = 0.148434
# Partial-AUC below fpr 0.0100 = 0.557789
# Partial-AUC below fpr 0.0500 = 0.649231
# Partial-AUC below fpr 0.1000 = 0.701053
# Partial-AUC below fpr 0.2000 = 0.763889
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.000000	0.001000	0.002000	0.000000
# 0.200000	0.005000	0.018000	0.055556
# 0.200000	0.010000	0.020000	0.100000
# 0.400000	0.050000	0.098000	0.204082
# 0.600000	0.100000	0.182000	0.329670
#
# Performance metrics for target positive proportion: 0.0600
# Fold 1: Number of positive samples = 60. Target proportion = 0.0600. Actual proportion = 0.0600
# Fold 2: Number of positive samples = 60. Target proportion = 0.0600. Actual proportion = 0.0600
# Fold 3: Number of positive samples = 60. Target proportion = 0.0600. Actual proportion = 0.0600
# Fold 4: Number of positive samples = 60. Target proportion = 0.0600. Actual proportion = 0.0600
# Fold 5: Number of positive samples = 60. Target proportion = 0.0600. Actual proportion = 0.0600
# Area under the ROC curve = 0.865917
# Average precision = 0.513664
# Partial-AUC below fpr 0.0100 = 0.564489
# Partial-AUC below fpr 0.0500 = 0.644444
# Partial-AUC below fpr 0.1000 = 0.697544
# Partial-AUC below fpr 0.2000 = 0.760509
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.050000	0.001000	0.002000	0.025000
# 0.133333	0.005000	0.008000	0.083333
# 0.183333	0.010000	0.012000	0.152778
# 0.466667	0.050000	0.052000	0.448718
# 0.633333	0.100000	0.104000	0.608974
#
# Performance metrics for target positive proportion: 0.1150
# Fold 1: Number of positive samples = 115. Target proportion = 0.1150. Actual proportion = 0.1150
# Fold 2: Number of positive samples = 115. Target proportion = 0.1150. Actual proportion = 0.1150
# Fold 3: Number of positive samples = 115. Target proportion = 0.1150. Actual proportion = 0.1150
# Fold 4: Number of positive samples = 115. Target proportion = 0.1150. Actual proportion = 0.1150
# Fold 5: Number of positive samples = 115. Target proportion = 0.1150. Actual proportion = 0.1150
# Area under the ROC curve = 0.866513
# Average precision = 0.643105
# Partial-AUC below fpr 0.0100 = 0.566528
# Partial-AUC below fpr 0.0500 = 0.645753
# Partial-AUC below fpr 0.1000 = 0.699771
# Partial-AUC below fpr 0.2000 = 0.760483
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.052174	0.001000	0.002000	0.026087
# 0.139130	0.005000	0.007000	0.099379
# 0.182609	0.010000	0.010000	0.182609
# 0.465217	0.050000	0.050000	0.465217
# 0.617391	0.100000	0.102000	0.605286
#
# Performance metrics for target positive proportion: 0.1700
# Fold 1: Number of positive samples = 170. Target proportion = 0.1700. Actual proportion = 0.1700
# Fold 2: Number of positive samples = 170. Target proportion = 0.1700. Actual proportion = 0.1700
# Fold 3: Number of positive samples = 170. Target proportion = 0.1700. Actual proportion = 0.1700
# Fold 4: Number of positive samples = 170. Target proportion = 0.1700. Actual proportion = 0.1700
# Fold 5: Number of positive samples = 170. Target proportion = 0.1700. Actual proportion = 0.1700
# Area under the ROC curve = 0.866065
# Average precision = 0.710208
# Partial-AUC below fpr 0.0100 = 0.567248
# Partial-AUC below fpr 0.0500 = 0.646637
# Partial-AUC below fpr 0.1000 = 0.699381
# Partial-AUC below fpr 0.2000 = 0.760376
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.052941	0.001000	0.002000	0.026471
# 0.141176	0.005000	0.006000	0.117647
# 0.182353	0.010000	0.010000	0.182353
# 0.464706	0.050000	0.050000	0.464706
# 0.617647	0.100000	0.100000	0.617647
#
# Performance metrics for target positive proportion: 0.2250
# Fold 1: Number of positive samples = 225. Target proportion = 0.2250. Actual proportion = 0.2250
# Fold 2: Number of positive samples = 225. Target proportion = 0.2250. Actual proportion = 0.2250
# Fold 3: Number of positive samples = 225. Target proportion = 0.2250. Actual proportion = 0.2250
# Fold 4: Number of positive samples = 225. Target proportion = 0.2250. Actual proportion = 0.2250
# Fold 5: Number of positive samples = 225. Target proportion = 0.2250. Actual proportion = 0.2250
# Area under the ROC curve = 0.866267
# Average precision = 0.757518
# Partial-AUC below fpr 0.0100 = 0.566723
# Partial-AUC below fpr 0.0500 = 0.648501
# Partial-AUC below fpr 0.1000 = 0.700538
# Partial-AUC below fpr 0.2000 = 0.760506
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.053333	0.001000	0.002000	0.026667
# 0.137778	0.005000	0.006000	0.114815
# 0.177778	0.010000	0.010000	0.177778
# 0.471111	0.050000	0.050000	0.471111
# 0.620000	0.100000	0.100000	0.620000
#
# Performance metrics for target positive proportion: 0.2800
# Fold 1: Number of positive samples = 280. Target proportion = 0.2800. Actual proportion = 0.2800
# Fold 2: Number of positive samples = 280. Target proportion = 0.2800. Actual proportion = 0.2800
# Fold 3: Number of positive samples = 280. Target proportion = 0.2800. Actual proportion = 0.2800
# Fold 4: Number of positive samples = 280. Target proportion = 0.2800. Actual proportion = 0.2800
# Fold 5: Number of positive samples = 280. Target proportion = 0.2800. Actual proportion = 0.2800
# Area under the ROC curve = 0.866389
# Average precision = 0.790454
# Partial-AUC below fpr 0.0100 = 0.565686
# Partial-AUC below fpr 0.0500 = 0.648718
# Partial-AUC below fpr 0.1000 = 0.700376
# Partial-AUC below fpr 0.2000 = 0.761062
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.050000	0.001000	0.002000	0.025000
# 0.135714	0.005000	0.006000	0.113095
# 0.178571	0.010000	0.010000	0.178571
# 0.471429	0.050000	0.050000	0.471429
# 0.617857	0.100000	0.100000	0.617857
#
# Performance metrics for target positive proportion: 0.3350
# Fold 1: Number of positive samples = 335. Target proportion = 0.3350. Actual proportion = 0.3350
# Fold 2: Number of positive samples = 335. Target proportion = 0.3350. Actual proportion = 0.3350
# Fold 3: Number of positive samples = 335. Target proportion = 0.3350. Actual proportion = 0.3350
# Fold 4: Number of positive samples = 335. Target proportion = 0.3350. Actual proportion = 0.3350
# Fold 5: Number of positive samples = 335. Target proportion = 0.3350. Actual proportion = 0.3350
# Area under the ROC curve = 0.865958
# Average precision = 0.814679
# Partial-AUC below fpr 0.0100 = 0.566189
# Partial-AUC below fpr 0.0500 = 0.648986
# Partial-AUC below fpr 0.1000 = 0.700581
# Partial-AUC below fpr 0.2000 = 0.759594
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.050746	0.001000	0.002000	0.025373
# 0.137313	0.005000	0.006000	0.114428
# 0.176119	0.010000	0.010000	0.176119
# 0.471642	0.050000	0.050000	0.471642
# 0.614925	0.100000	0.100000	0.614925
#
# Performance metrics for target positive proportion: 0.3900
# Fold 1: Number of positive samples = 390. Target proportion = 0.3900. Actual proportion = 0.3900
# Fold 2: Number of positive samples = 390. Target proportion = 0.3900. Actual proportion = 0.3900
# Fold 3: Number of positive samples = 390. Target proportion = 0.3900. Actual proportion = 0.3900
# Fold 4: Number of positive samples = 390. Target proportion = 0.3900. Actual proportion = 0.3900
# Fold 5: Number of positive samples = 390. Target proportion = 0.3900. Actual proportion = 0.3900
# Area under the ROC curve = 0.865992
# Average precision = 0.833749
# Partial-AUC below fpr 0.0100 = 0.566293
# Partial-AUC below fpr 0.0500 = 0.649915
# Partial-AUC below fpr 0.1000 = 0.701390
# Partial-AUC below fpr 0.2000 = 0.758611
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.048718	0.001000	0.002000	0.024359
# 0.135897	0.005000	0.006000	0.113248
# 0.176923	0.010000	0.010000	0.176923
# 0.474359	0.050000	0.050000	0.474359
# 0.610256	0.100000	0.100000	0.610256
#
# Performance metrics for target positive proportion: 0.4450
# Fold 1: Number of positive samples = 445. Target proportion = 0.4450. Actual proportion = 0.4450
# Fold 2: Number of positive samples = 445. Target proportion = 0.4450. Actual proportion = 0.4450
# Fold 3: Number of positive samples = 445. Target proportion = 0.4450. Actual proportion = 0.4450
# Fold 4: Number of positive samples = 445. Target proportion = 0.4450. Actual proportion = 0.4450
# Fold 5: Number of positive samples = 445. Target proportion = 0.4450. Actual proportion = 0.4450
# Area under the ROC curve = 0.866054
# Average precision = 0.848178
# Partial-AUC below fpr 0.0100 = 0.566597
# Partial-AUC below fpr 0.0500 = 0.650913
# Partial-AUC below fpr 0.1000 = 0.701076
# Partial-AUC below fpr 0.2000 = 0.757079
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.050562	0.001000	0.002000	0.025281
# 0.134831	0.005000	0.006000	0.112360
# 0.175281	0.010000	0.010000	0.175281
# 0.476404	0.050000	0.050000	0.476404
# 0.606742	0.100000	0.100000	0.606742
#
# Performance metrics for target positive proportion: 0.5000
# Fold 1: Number of positive samples = 500. Target proportion = 0.5000. Actual proportion = 0.5000
# Fold 2: Number of positive samples = 500. Target proportion = 0.5000. Actual proportion = 0.5000
# Fold 3: Number of positive samples = 500. Target proportion = 0.5000. Actual proportion = 0.5000
# Fold 4: Number of positive samples = 500. Target proportion = 0.5000. Actual proportion = 0.5000
# Fold 5: Number of positive samples = 500. Target proportion = 0.5000. Actual proportion = 0.5000
# Area under the ROC curve = 0.866104
# Average precision = 0.859615
# Partial-AUC below fpr 0.0100 = 0.565427
# Partial-AUC below fpr 0.0500 = 0.650872
# Partial-AUC below fpr 0.1000 = 0.701221
# Partial-AUC below fpr 0.2000 = 0.754356
# TPR	FPR_target	FPR_actual	TPR_scaled
# 0.050000	0.001000	0.002000	0.025000
# 0.134000	0.005000	0.006000	0.111667
# 0.176000	0.010000	0.010000	0.176000
# 0.478000	0.050000	0.050000	0.478000
# 0.602000	0.100000	0.100000	0.602000

# %%
# Plot directly from the results dict
# plot_performance_comparison(results, output_dir)

# Load the results from the pickle files and generate plots
results = dict()
for m in methods:
    fname = os.path.join(output_dir, 'results_{}.pkl'.format(m))
    with open(fname, 'rb') as fp:
        results[m] = pickle.load(fp)

plot_performance_comparison(results, output_dir)
